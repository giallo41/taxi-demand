# %%
import numpy as np
import pandas as pd


from metric import *


import matplotlib.pyplot as plt
from matplotlib import pyplot
# %matplotlib inline

# %%
DATA_FOLDER = '/data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/datasets/model_2018/'
x_st_train = np.load(DATA_FOLDER+'X_train_data_st_30min_16ch_ori.npz')['arr_0']
x_ed_train = np.load(DATA_FOLDER+'X_train_data_ed_30min_16ch_ori.npz')['arr_0']
print (x_st_train.shape, x_ed_train.shape)
# Out:
# (5744, 50, 50, 10) (5744, 50, 50, 16)

# %%
def plot_img3(img):
    
    fig = plt.figure(figsize=(4, 4), dpi=300)
    ax = plt.subplot(111) 
    tmp_img = []
    
    data_max = img.max()
    img = img / 2500 #data_max
    img = img*80
#    img = img.astype(int)

#    img = np.log(img+1)
#    img = img *100
    if len(img.shape)<3 or img.shape[2] < 3 : 
        img = np.reshape(img, (img.shape[0], img.shape[1], 1))
        tmp_img = np.concatenate((img,img,img), axis=2)
    
#    tmp_img = np.asarray(tmp_img)
    
#    print (tmp_img.shape)
    
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    plt.imshow(tmp_img, cmap='autumn_r')
    plt.show()
    return fig

idx = 150
x_st_input = x_st_train[idx, :, :, 0]
fig = plot_img3(np.reshape(x_st_input, (50, 50)))
