# %%
import numpy as np
import pandas as pd


from metric import *


import matplotlib.pyplot as plt
from matplotlib import pyplot
# %matplotlib inline

my_dpi = 300

# %% [markdown]
# ## ML / 통계 모델들 결과

# %% [markdown]
# ## XGboost

# %%
DATA_FOLDER = '/data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/stats_base/'
m_name = 'y_t1_test_xgb'
print ('XGB T1:')
mape_lst_xg_t1, rmse_lst_xg_t1, maa_lst_xg_t1= chk_1ch_output(DATA_FOLDER+m_name)
m_name = 'y_t2_test_xgb'
print ('XGB T2:')
mape_lst_xg_t2, rmse_lst_xg_t2, maa_lst_xg_t2 = chk_1ch_output(DATA_FOLDER+m_name)

chk_event_metric_3by3(DATA_FOLDER+m_name)
# Out:
# XGB T1:
# ## Model Name : /data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/stats_base/y_t1_test_xgb
# MAPE 11 : 0.475
# RMSE 11 : 32.235
#
# MAPE all : 0.197
# RMSE all : 8.081
#
# XGB T2:
# ## Model Name : /data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/stats_base/y_t2_test_xgb
# MAPE 11 : 0.539
# RMSE 11 : 44.530
#
# MAPE all : 0.211
# RMSE all : 11.091
#
# ## ---- Event Metric -----
# - True Max 1518 , Pred Max 251
# - True Avg 67.363 , Pred Avg 16.517
# - Event MAPE : 0.636
# - Event RMSE : 179.873

# %% [markdown]
# ## ARIMA

# %%
DATA_FOLDER = '/data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/stats_base/'
m_name = 'y_t1_test_arima'
print ('ARIMA T1:')
mape_lst_arima_t1, rmse_lst_arima_t1, maa_lst_arima_t1= chk_1ch_output(DATA_FOLDER+m_name)
m_name = 'y_t2_test_arima'
print ('ARIMA T2:')
mape_lst_arima_t2, rmse_lst_arima_t2, maa_lst_arima_t2 = chk_1ch_output(DATA_FOLDER+m_name)

chk_event_metric_3by3(DATA_FOLDER+m_name)
# Out:
# ARIMA T1:
# ## Model Name : /data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/stats_base/y_t1_test_arima
# MAPE 11 : 0.581
# RMSE 11 : 49.041
#
# MAPE all : 0.231
# RMSE all : 12.259
#
# ARIMA T2:
# ## Model Name : /data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/stats_base/y_t2_test_arima
# MAPE 11 : 0.631
# RMSE 11 : 57.834
#
# MAPE all : 0.247
# RMSE all : 14.461
#
# ## ---- Event Metric -----
# - True Max 1518 , Pred Max 196
# - True Avg 67.363 , Pred Avg 15.626
# - Event MAPE : 0.678
# - Event RMSE : 180.821

# %% [markdown]
# # Kakao Basemodel  (SEO)
#
# ### 1) Base  :
# DATA_FOLDER = '/data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/0828_baseline_output/'  <br>
# m_name = '0822_kakao_baseline_skip_0.01' <br>
#
# ### 2) Base + End
# DATA_FOLDER = '/data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/0828_baseline_output/'  <br>
# m_name = '0822_kakao_baseline_end_skip_bn_0.01' <br>
#
# ### 3) Base + Temporal
# DATA_FOLDER = '/data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/' <br>
# m_name = 'kakao_baseline_temporal_skip_0.01' <br>
#
#
# ### 4) Base + End + Temp
# DATA_FOLDER = '/data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/0828_baseline_output/'  <br>
# m_name = '0822_kakao_baseline_all_concat_skip_end_bn_0.01' <br>

# %%
print ('')
print ('1) Base : ')
DATA_FOLDER = '/data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/0828_baseline_output/' 
m_name = '0822_kakao_baseline_skip_0.01' 
mape_lst_base1_t1, rmse_lst_base1_t1, maa_lst_base1_t1 = chk_1ch_output(DATA_FOLDER+m_name)
chk_event_metric_3by3(DATA_FOLDER+m_name)

print ('')
print ('2) Base + End : ')
DATA_FOLDER = '/data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/0828_baseline_output/' 
m_name = '0822_kakao_baseline_end_skip_bn_0.01' 
mape_lst_base2_t1, rmse_lst_base2_t1, maa_lst_base2_t1 = chk_1ch_output(DATA_FOLDER+m_name)
chk_event_metric_3by3(DATA_FOLDER+m_name)

print ('')
print ('3) Base + Temporal : ')
DATA_FOLDER = '/data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/' 
m_name = 'kakao_baseline_temporal_skip_0.01' 
mape_lst_base3_t1, rmse_lst_base3_t1, maa_lst_base3_t1 = chk_1ch_output(DATA_FOLDER+m_name)
chk_event_metric_3by3(DATA_FOLDER+m_name)

print ('')
print ('4) Base + End + Temporal: ')
DATA_FOLDER = '/data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/0828_baseline_output/' 
m_name = '0822_kakao_baseline_all_concat_skip_end_bn_0.01' 
mape_lst_base4_t1, rmse_lst_base4_t1, maa_lst_base4_t1 = chk_1ch_output(DATA_FOLDER+m_name)
chk_event_metric_3by3(DATA_FOLDER+m_name)
# Out:
# 1) Base :
# ## Model Name : /data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/0828_baseline_output/0822_kakao_baseline_skip_0.01
# MAPE 11 : 0.368
# RMSE 11 : 28.095
#
# MAPE all : 0.189
# RMSE all : 7.063
#
# ## ---- Event Metric -----
# - True Max 1518 , Pred Max 264
# - True Avg 71.094 , Pred Avg 23.669
# - Event MAPE : 0.493
# - Event RMSE : 175.790
#
# 2) Base + End :
# ## Model Name : /data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/0828_baseline_output/0822_kakao_baseline_end_skip_bn_0.01
# MAPE 11 : 0.362
# RMSE 11 : 26.757
#
# MAPE all : 0.186
# RMSE all : 6.732
#
# ## ---- Event Metric -----
# - True Max 1518 , Pred Max 309
# - True Avg 71.094 , Pred Avg 28.090
# - Event MAPE : 0.463
# - Event RMSE : 163.862
#
# 3) Base + Temporal :
# ## Model Name : /data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/kakao_baseline_temporal_skip_0.01
# MAPE 11 : 0.360
# RMSE 11 : 26.608
#
# MAPE all : 0.180
# ...

# %% [markdown]
# ## Performance 비교

# %% [markdown]
# #### 1. MAPE treshhold 기준 성능 비교

# %%
fig = plt.figure(figsize=(6, 4), dpi=my_dpi)
ax = plt.subplot(111)  

#for y in list (np.arange(30, 71, 10)) :#range(0.3, 590,100):    
#    plt.plot(range(0, 21), [y] * len(range(0, 21)), "-", lw=1, color="black", alpha=0.1) 
    
#for x in list (np.arange(0, 21, 5)) :#range(0.3, 590,100):    
#    plt.plot([x] * len(range(30, 71)) , range(30, 71), "-", lw=1, color="black", alpha=0.1)  

ax.grid(linestyle='-', linewidth=0.5)

ytick_list = np.arange(30, 71, 10)
trs_list = range(1, 21)
trs_plot_list = np.arange(0, 21, 5)
#plt.plot(trs_list, ny_list, 'r--', trs_list, seo_list)
plt.title('MAPE Performance',  fontsize=14)
plt.plot(trs_list, np.multiply(100, mape_lst_xg_t1), 'k-.', label="XGboost")
plt.plot(trs_list, np.multiply(100, mape_lst_arima_t1), 'k:', label="ARIMA")
plt.plot(trs_list, np.multiply(100, mape_lst_base1_t1), 'g--', linewidth=2, label="Base")
plt.plot(trs_list, np.multiply(100, mape_lst_base2_t1), 'b-..', label="Base + End")
plt.plot(trs_list, np.multiply(100, mape_lst_base3_t1), 'c', label="Base + Temp")
plt.plot(trs_list, np.multiply(100, mape_lst_base4_t1), 'r*-', label="Base + Temp + End")
plt.tick_params(axis="both", which="both", bottom="off", top="off",    
                    labelbottom="on", left="off", right="off", labelleft="on") 

plt.xticks(trs_plot_list, trs_plot_list, fontsize=10,color='black', horizontalalignment='center')
plt.yticks(ytick_list, ytick_list, fontsize=10,color='black', horizontalalignment='center')
plt.xlabel('# or more data included',  fontsize=12)
plt.ylabel('MAPE(%)' ,  fontsize=12)

#ax.spines["top"].set_visible(False)    
#ax.spines["bottom"].set_visible(False)    
#ax.spines["right"].set_visible(False)    
#ax.spines["left"].set_visible(False)  
plt.legend(bbox_to_anchor=(0.53, 0.74), loc=6,ncol=1)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
fig = plt.figure(figsize=(6, 4), dpi=my_dpi)
ax = plt.subplot(111)  

#for y in list (np.arange(10, 80, 10)) :#range(0.3, 590,100):    
#    plt.plot(range(1, 21), [y] * len(range(1, 21)), "--", lw=1, color="black", alpha=0.1)   
        
ax.grid(linestyle='-', linewidth=0.5)

ytick_list = np.arange(10, 75, 10)
trs_list = range(1, 21)
trs_plot_list = np.arange(0, 21, 5)
#plt.plot(trs_list, ny_list, 'r--', trs_list, seo_list)
plt.title('RMSE Performance',  fontsize=14)
plt.plot(trs_list, np.multiply(1, rmse_lst_xg_t1), 'k-.', label="XGboost")
plt.plot(trs_list, np.multiply(1, rmse_lst_arima_t1), 'k:', label="ARIMA")
plt.plot(trs_list, np.multiply(1, rmse_lst_base1_t1), 'g--', linewidth=2, label="Base")
plt.plot(trs_list, np.multiply(1, rmse_lst_base2_t1), 'b-..', label="Base + End")
plt.plot(trs_list, np.multiply(1, rmse_lst_base3_t1), 'c', label="Base + Temp")
plt.plot(trs_list, np.multiply(1, rmse_lst_base4_t1), 'r*-', label="Base + Temp + End")
plt.tick_params(axis="both", which="both", bottom="off", top="off",    
                    labelbottom="on", left="off", right="off", labelleft="on") 

plt.xticks(trs_plot_list, trs_plot_list, fontsize=10,color='black', horizontalalignment='center')
plt.yticks(ytick_list, ytick_list, fontsize=10,color='black', horizontalalignment='center')
plt.xlabel('# or more data included',  fontsize=12)
plt.ylabel('RMSE' ,  fontsize=12)
plt.legend()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# plt.figure(figsize=(10, 8))
#
# trs_list = range(1, 21)
# #plt.plot(trs_list, ny_list, 'r--', trs_list, seo_list)
# plt.title('RMSE trs Performance')
# plt.plot(trs_list, rmse_lst_xg_t1, 'k:', label="XGboost")
# plt.plot(trs_list, rmse_lst_arima_t1, 'k.', label="ARIMA")
# plt.plot(trs_list, rmse_lst_base1_t1, 'g--', label="Base")
# plt.plot(trs_list, rmse_lst_base2_t1, 'b-.', label="Base + End")
# plt.plot(trs_list, rmse_lst_base3_t1, 'c', label="Bsse + Temp")
# plt.plot(trs_list, rmse_lst_base4_t1, 'r-', label="Base + Temp + End")
# plt.xlabel('Trs # or more ')
# plt.ylabel('RMSE(%)')
# plt.legend()

# %% [markdown]
# plt.figure(figsize=(10, 8))
#
# trs_list = np.arange(0, 1.05, 0.1)
# #plt.plot(trs_list, ny_list, 'r--', trs_list, seo_list)
# plt.title('MAA trs Performance')
# plt.plot(trs_list, maa_lst_xg_t1, 'k:', label="XGboost")
# plt.plot(trs_list, maa_lst_base1_t1, 'g--', label="Base")
# plt.plot(trs_list, maa_lst_base2_t1, 'b-.', label="Base + End")
# plt.plot(trs_list, maa_lst_base3_t1, 'c', label="Bsse + Temp")
# plt.plot(trs_list, maa_lst_base4_t1, 'r-', label="Base + Temp + End")
# plt.xlabel('Trs (% error range ) ')
# plt.ylabel('MAA(%)')
# plt.legend()

# %% [markdown]
# ## NYC - dataset
#
# DATA_FOLDER = '/data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/NY/'

# %%
print ('')
print ('1) Base : ')
DATA_FOLDER = '/data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/NY/'
m_name = '0826_v2_1_baseline_0.01_p50' 
mape_lst_base1_t1, rmse_lst_base1_t1, maa_lst_base1_t1 = chk_1ch_output(DATA_FOLDER+m_name)

print ('')
print ('2) Base + End : ')

m_name = '0826_v2_1_baseline_end_bn_0.01_p50' 
mape_lst_base2_t1, rmse_lst_base2_t1, maa_lst_base2_t1 = chk_1ch_output(DATA_FOLDER+m_name)


print ('')
print ('3) Base + Temporal : ')

m_name = '0826_v2_1_baseline_temporal_0.01_p50' 
mape_lst_base3_t1, rmse_lst_base3_t1, maa_lst_base3_t1 = chk_1ch_output(DATA_FOLDER+m_name)


print ('')
print ('4) Base + End + Temporal: ')

m_name = '0826_v2_1_all_concat_0.01_p50' 
mape_lst_base4_t1, rmse_lst_base4_t1, maa_lst_base4_t1 = chk_1ch_output(DATA_FOLDER+m_name)
# Out:
# 1) Base :
# ## Model Name : /data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/NY/0826_v2_1_baseline_0.01_p50
# MAPE 11 : 0.175
# RMSE 11 : 28.972
#
# MAPE all : 0.168
# RMSE all : 14.749
#
#
# 2) Base + End :
# ## Model Name : /data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/NY/0826_v2_1_baseline_end_bn_0.01_p50
# MAPE 11 : 0.170
# RMSE 11 : 30.697
#
# MAPE all : 0.165
# RMSE all : 15.620
#
#
# 3) Base + Temporal :
# ## Model Name : /data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/NY/0826_v2_1_baseline_temporal_0.01_p50
# MAPE 11 : 0.156
# RMSE 11 : 25.305
#
# MAPE all : 0.155
# RMSE all : 12.887
#
#
# 4) Base + End + Temporal:
# ## Model Name : /data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/model_output/NY/0826_v2_1_all_concat_0.01_p50
# MAPE 11 : 0.154
# RMSE 11 : 25.178
#
# MAPE all : 0.157
# RMSE all : 12.824

# %%
fig = plt.figure(figsize=(6, 4), dpi=my_dpi)
ax = plt.subplot(111)  

#for y in list (np.arange(30, 71, 10)) :#range(0.3, 590,100):    
#    plt.plot(range(0, 21), [y] * len(range(0, 21)), "-", lw=1, color="black", alpha=0.1) 
    
#for x in list (np.arange(0, 21, 5)) :#range(0.3, 590,100):    
#    plt.plot([x] * len(range(30, 71)) , range(30, 71), "-", lw=1, color="black", alpha=0.1)  

ax.grid(linestyle='-', linewidth=0.5)

ytick_list = np.arange(10, 41, 5)
trs_list = range(1, 21)
trs_plot_list = np.arange(0, 21, 5)
#plt.plot(trs_list, ny_list, 'r--', trs_list, seo_list)
plt.title('MAPE Performance(NYC)',  fontsize=14)
plt.plot(trs_list, np.multiply(100, mape_lst_base1_t1), 'g--', linewidth=2, label="Base")
plt.plot(trs_list, np.multiply(100, mape_lst_base2_t1), 'b-..', label="Base + End")
plt.plot(trs_list, np.multiply(100, mape_lst_base3_t1), 'c', label="Base + Temp")
plt.plot(trs_list, np.multiply(100, mape_lst_base4_t1), 'r*-', label="Base + Temp + End")
plt.tick_params(axis="both", which="both", bottom="off", top="off",    
                    labelbottom="on", left="off", right="off", labelleft="on") 

plt.xticks(trs_plot_list, trs_plot_list, fontsize=10,color='black', horizontalalignment='center')
plt.yticks(ytick_list, ytick_list, fontsize=10,color='black', horizontalalignment='center')
plt.xlabel('# or more data included',  fontsize=12)
plt.ylabel('MAPE(%)' ,  fontsize=12)

#ax.spines["top"].set_visible(False)    
#ax.spines["bottom"].set_visible(False)    
#ax.spines["right"].set_visible(False)    
#ax.spines["left"].set_visible(False)  
plt.legend(bbox_to_anchor=(0.53, 0.74), loc=6,ncol=1)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
fig = plt.figure(figsize=(6, 4), dpi=my_dpi)
ax = plt.subplot(111)  

#for y in list (np.arange(10, 80, 10)) :#range(0.3, 590,100):    
#    plt.plot(range(1, 21), [y] * len(range(1, 21)), "--", lw=1, color="black", alpha=0.1)   
        
ax.grid(linestyle='-', linewidth=0.5)

ytick_list = np.arange(15, 41, 5)
trs_list = range(1, 21)
trs_plot_list = np.arange(0, 21, 5)
#plt.plot(trs_list, ny_list, 'r--', trs_list, seo_list)
plt.title('RMSE Performance(NYC)',  fontsize=14)
plt.plot(trs_list, np.multiply(1, rmse_lst_base1_t1), 'g--', linewidth=2, label="Base")
plt.plot(trs_list, np.multiply(1, rmse_lst_base2_t1), 'b-..', label="Base + End")
plt.plot(trs_list, np.multiply(1, rmse_lst_base3_t1), 'c', label="Base + Temp")
plt.plot(trs_list, np.multiply(1, rmse_lst_base4_t1), 'r*-', label="Base + Temp + End")
plt.tick_params(axis="both", which="both", bottom="off", top="off",    
                    labelbottom="on", left="off", right="off", labelleft="on") 

plt.xticks(trs_plot_list, trs_plot_list, fontsize=10,color='black', horizontalalignment='center')
plt.yticks(ytick_list, ytick_list, fontsize=10,color='black', horizontalalignment='center')
plt.xlabel('# or more data included',  fontsize=12)
plt.ylabel('RMSE' ,  fontsize=12)
plt.legend()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# plt.figure(figsize=(10, 8))
#
# trs_list = range(1, 21)
# #plt.plot(trs_list, ny_list, 'r--', trs_list, seo_list)
# plt.title('RMSE Performance(NYC)')
# plt.plot(trs_list, rmse_lst_base1_t1, 'g--', label="Base")
# plt.plot(trs_list, rmse_lst_base2_t1, 'b-.', label="Base + End")
# plt.plot(trs_list, rmse_lst_base3_t1, 'c', label="Bsse + Temp")
# plt.plot(trs_list, rmse_lst_base4_t1, 'r-', label="Base + Temp + End")
# plt.xlabel('Trs # or more ')
# plt.ylabel('RMSE(%)')
# plt.legend()

# %% [markdown]
# ## Multi-Task 비교 (SEO vs NYC )
#
# #### 1) Base ( Start (t0) + End (t0) + Temp (t1)  ) -> Y (t1)
#
# #### 2) Multi 2 task ( Start (t0) + End (t0) + Temp (t1)  ) -> Y (t1), Y(t2) - t1, t2 shared embedding
#
# #### 3) Base ( Start (t0) + End (t0) + Temp (t2)  ) -> Y (t2)

# %%
print ('')
print ('1) Base : t1 -> t1 => Y(t1)')
DATA_FOLDER = '/data/public/rw/prj-mobility/taxi-demand/output_file/MODEL_V1_SEO/'
m_name = 'MODEL_V1_SEO_0827_006_SEO_V1_base_4' 
mape_lst_base1_t1_2ch, rmse_lst_base1_t1_2ch, maa_lst_base1_t1_2ch = chk_1ch_output(DATA_FOLDER+m_name)
# Out:
# 1) Base : t1 -> t1 => Y(t1)
# ## Model Name : /data/public/rw/prj-mobility/taxi-demand/output_file/MODEL_V1_SEO/MODEL_V1_SEO_0827_006_SEO_V1_base_4
# MAPE 11 : 0.381
# RMSE 11 : 34.505
#
# MAPE all : 0.188
# RMSE all : 8.622

# %% [markdown]
# ### NYC 2ch task

# %%
print ('')
print ('1) Base : t1 -> t1 => Y(t1)')
DATA_FOLDER = '/data/public/rw/prj-mobility/taxi-demand/output_file/MODEL_V1_NYC/'
m_name = 'MODEL_V1_NYC_0827_001_NY_V1_base_1_re_re_p50' 
mape_lst_base1_t1_2ch, rmse_lst_base1_t1_2ch, maa_lst_base1_t1_2ch = chk_1ch_output(DATA_FOLDER+m_name)

print ('2) Base : t1 & t2 embedding -> t1 => Y(t1) & t2=>Y(t2) ')
m_name = 'MODEL_V1_NYC_0827_002_NY_V1_base_3b_re_p50t1'
print ('T1 : ')
mape_lst_base1_t2_2ch, rmse_lst_base1_t2_2ch, maa_lst_base1_t2_2ch = chk_1ch_output(DATA_FOLDER+m_name)

m_name = 'MODEL_V1_NYC_0827_002_NY_V1_base_3b_re_p50t2'
print ('T2 : ')
mape_lst_base1_t3_2ch, rmse_lst_base1_t3_2ch, maa_lst_base1_t3_2ch = chk_1ch_output(DATA_FOLDER+m_name)

print ('3) Base : t2 -> t2 => Y(t2) ')
m_name = 'MODEL_V1_NYC_0827_003_NY_V1_base_4_re_p50' 
mape_lst_base1_t4_2ch, rmse_lst_base1_t4_2ch, maa_lst_base1_t4_2ch = chk_1ch_output(DATA_FOLDER+m_name)
# Out:
# 1) Base : t1 -> t1 => Y(t1)
# ## Model Name : /data/public/rw/prj-mobility/taxi-demand/output_file/MODEL_V1_NYC/MODEL_V1_NYC_0827_001_NY_V1_base_1_re_re_p50
# MAPE 11 : 0.155
# RMSE 11 : 26.841
#
# MAPE all : 0.159
# RMSE all : 13.668
#
# T1 :
# ## Model Name : /data/public/rw/prj-mobility/taxi-demand/output_file/MODEL_V1_NYC/MODEL_V1_NYC_0827_002_NY_V1_base_3b_re_p50t1
# MAPE 11 : 0.155
# RMSE 11 : 25.359
#
# MAPE all : 0.153
# RMSE all : 12.916
#
# T2 :
# ## Model Name : /data/public/rw/prj-mobility/taxi-demand/output_file/MODEL_V1_NYC/MODEL_V1_NYC_0827_002_NY_V1_base_3b_re_p50t2
# MAPE 11 : 0.169
# RMSE 11 : 30.098
#
# MAPE all : 0.160
# RMSE all : 15.318
#
# ## Model Name : /data/public/rw/prj-mobility/taxi-demand/output_file/MODEL_V1_NYC/MODEL_V1_NYC_0827_003_NY_V1_base_4_re_p50
# MAPE 11 : 0.173
# RMSE 11 : 29.814
#
# MAPE all : 0.158
# RMSE all : 15.172

# %%
fig = plt.figure(figsize=(6, 4), dpi=my_dpi)
ax = plt.subplot(111)  
        
ax.grid(linestyle='-', linewidth=0.5)
ytick_list = np.arange(10, 41, 5)
trs_list = range(1, 21)
trs_plot_list = np.arange(0, 21, 5)

plt.title('MAPE Performance(NYC)')

plt.plot(trs_list, np.multiply(100, mape_lst_base1_t1_2ch), 'g-.', label="Base-T1")
plt.plot(trs_list, np.multiply(100, mape_lst_base1_t2_2ch), 'b-', label="Multi-T1")
plt.plot(trs_list, np.multiply(100, mape_lst_base1_t3_2ch), 'c-', label="Multi-T2")
plt.plot(trs_list, np.multiply(100, mape_lst_base1_t4_2ch), 'r-.', label="Base-T2")

plt.tick_params(axis="both", which="both", bottom="off", top="off",    
                    labelbottom="on", left="off", right="off", labelleft="on") 

plt.xticks(trs_plot_list, trs_plot_list, fontsize=10,color='black', horizontalalignment='center')
plt.yticks(ytick_list, ytick_list, fontsize=10,color='black', horizontalalignment='center')
plt.xlabel('# or more data included',  fontsize=12)
plt.ylabel('MAPE(%)' ,  fontsize=12)
 
plt.legend(bbox_to_anchor=(0.53, 0.74), loc=6,ncol=1)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Multi-Task 비교 NYC

# %%
fig = plt.figure(figsize=(6, 4), dpi=my_dpi)
ax = plt.subplot(111)  

#for y in list (np.arange(10, 80, 10)) :#range(0.3, 590,100):    
#    plt.plot(range(1, 21), [y] * len(range(1, 21)), "--", lw=1, color="black", alpha=0.1)   
        
ax.grid(linestyle='-', linewidth=0.5)

ytick_list = np.arange(15, 41, 5)
trs_list = range(1, 21)
trs_plot_list = np.arange(0, 21, 5)
#plt.plot(trs_list, ny_list, 'r--', trs_list, seo_list)
plt.title('RMSE Performance(NYC Multi-task)',  fontsize=14)
plt.plot(trs_list, rmse_lst_base1_t1_2ch, 'g-.', label="Base-T1")
plt.plot(trs_list, rmse_lst_base1_t2_2ch, 'b-', label="Multi-T1")
plt.plot(trs_list, rmse_lst_base1_t3_2ch, 'm-', label="Multi-T2")
plt.plot(trs_list, rmse_lst_base1_t4_2ch, 'r-.', label="Base-T2")

plt.tick_params(axis="both", which="both", bottom="off", top="off",    
                    labelbottom="on", left="off", right="off", labelleft="on") 

plt.xticks(trs_plot_list, trs_plot_list, fontsize=10,color='black', horizontalalignment='center')
plt.yticks(ytick_list, ytick_list, fontsize=10,color='black', horizontalalignment='center')
plt.xlabel('# or more data included',  fontsize=12)
plt.ylabel('RMSE' ,  fontsize=12)
plt.legend()
#plt.legend(bbox_to_anchor=(0.53, 0.74), loc=6,ncol=1)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
plt.figure(figsize=(10, 8))

trs_list = range(1, 21)
#plt.plot(trs_list, ny_list, 'r--', trs_list, seo_list)
plt.title('MAPE trs Performance(NYC-multi)')
#plt.plot(trs_list, mape_lst_xg_t1, 'k:', label="XGboost")
plt.plot(trs_list, mape_lst_base1_t1_2ch, 'g--', label="Base-T1")
plt.plot(trs_list, mape_lst_base1_t2_2ch, 'b-.', label="Multi-T1")
plt.plot(trs_list, mape_lst_base1_t3_2ch, 'c', label="Multi-T2")
plt.plot(trs_list, mape_lst_base1_t4_2ch, 'r-', label="Base-T2")
plt.xlabel('Trs # or more ')
plt.ylabel('MAPE(%)')
plt.legend()

# %%
plt.figure(figsize=(10, 8))

trs_list = range(1, 21)
#plt.plot(trs_list, ny_list, 'r--', trs_list, seo_list)
plt.title('RMSE trs Performance(NYC-multi)')
#plt.plot(trs_list, mape_lst_xg_t1, 'k:', label="XGboost")
plt.plot(trs_list, rmse_lst_base1_t1_2ch, 'g--', label="Base-T1")
plt.plot(trs_list, rmse_lst_base1_t2_2ch, 'b-.', label="Multi-T1")
plt.plot(trs_list, rmse_lst_base1_t3_2ch, 'c', label="Multi-T2")
plt.plot(trs_list, rmse_lst_base1_t4_2ch, 'r-', label="Base-T2")
plt.xlabel('Trs # or more ')
plt.ylabel('MAPE(%)')
plt.legend()

# %% [markdown]
# # DATA Distribution

# %%
DATA_FOLDER = '/data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/'

NY_x_st_train = np.load(DATA_FOLDER+'datasets/NY_data/train_st_x_2d.npz')['arr_0']
SEO_x_st_train = np.load(DATA_FOLDER+'datasets/model_2018/X_train_data_st_30min_16ch_ori.npz')['arr_0']

print (NY_x_st_train.shape, SEO_x_st_train.shape)
print (NY_x_st_train.mean(), SEO_x_st_train.mean(), NY_x_st_train.max(), SEO_x_st_train.max())
print (NY_x_st_train.std(), SEO_x_st_train.std())
trs_list = list(range(0, 100))

ny_list = []
seo_list = []

NY_onech = NY_x_st_train[:,:,:,0]
SEO_onech = SEO_x_st_train[:,:,:,0]

for lst in trs_list:
    ny_tmp = np.average(NY_onech>lst)
    ny_list.append(1-ny_tmp)
    
    seo_tmp = np.average(SEO_onech>lst)
    seo_list.append(1-seo_tmp)
    
    #print ('Over ', lst, ' data(%)', 'NY :%.2f'%(ny_tmp*100), 'SE : %.2f'%(seo_tmp*100))
    
plt.figure(figsize=(12, 6))

#plt.plot(trs_list, ny_list, 'r--', trs_list, seo_list)
plt.title('Data Distribution')
plt.plot(trs_list, ny_list, 'r--', label="NYC")
plt.plot(trs_list, seo_list, label="SEO")
plt.legend()
# Out:
# (1904, 10, 20, 8) (5744, 50, 50, 10)
# 37.71580915178571 7.235995160167131 1149.0 4491.0
# 105.98825765296979 18.86450655708535

# %% [markdown]
# ## Data Map

# %%
DATA_FOLDER = '/data/public/rw/prj-mobility/10.195.12.143/kakaobrain/taxi/datasets/model_2018/'
x_st_train = np.load(DATA_FOLDER+'X_train_data_st_30min_16ch_ori.npz')['arr_0']
x_ed_train = np.load(DATA_FOLDER+'X_train_data_ed_30min_16ch_ori.npz')['arr_0']
print (x_st_train.shape, x_ed_train.shape)
# Out:
# (5744, 50, 50, 10) (5744, 50, 50, 16)

# %%
idx = 24
x_st_input = x_st_train[idx, :, :, 0]
plot_img(np.reshape(x_st_input, (50, 50)))

# %%
x_ed_input = x_ed_train[idx, :, :, 0]
plot_img(np.reshape(x_ed_input, (50, 50)))
